# %%
import pandas as pd

# %%
df =pd.read_csv(r"C:\Users\ASUS\Downloads\customer_orders_raw_messy.csv")
df
# Out:
#      Order_ID Customer_Name    Age  Gender       City          State  \
# 0        1001    Neha Patel   27.0    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36.0    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42.0  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47.0  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38.0    Male      Delhi    Maharashtra
# ..        ...           ...    ...     ...        ...            ...
# 305      1006   Arjun Mehta  150.0  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43.0    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27.0    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48.0  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta  999.0  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# ...

# %%
df.shape
# Out:
# (310, 18)

# %% [markdown]
# # Change Type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        310 non-null    int64
#  1   Customer_Name   310 non-null    object
#  2   Age             306 non-null    float64
#  3   Gender          310 non-null    object
#  4   City            310 non-null    object
#  5   State           310 non-null    object
#  6   Email           310 non-null    object
#  7   Phone           310 non-null    object
#  8   Order_Date      310 non-null    object
#  9   Delivery_Date   310 non-null    object
#  10  Product         310 non-null    object
#  11  Category        310 non-null    object
#  12  Quantity        310 non-null    int64
#  13  Price           310 non-null    int64
#  14  Discount        310 non-null    float64
#  15  Revenue         310 non-null    float64
#  16  Payment_Method  310 non-null    object
# ...

# %%
df['Order_ID']=df['Order_ID'].astype (str)
df['Customer_Name']=df['Customer_Name'].astype (str)
df['Age']=df['Age'].astype (float)
df['Order_Date']= pd.to_datetime(df['Order_Date'], errors='coerce')
df['Delivery_Date']= pd.to_datetime(df['Delivery_Date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        310 non-null    object
#  1   Customer_Name   310 non-null    object
#  2   Age             306 non-null    float64
#  3   Gender          310 non-null    object
#  4   City            310 non-null    object
#  5   State           310 non-null    object
#  6   Email           310 non-null    object
#  7   Phone           310 non-null    object
#  8   Order_Date      300 non-null    datetime64[ns]
#  9   Delivery_Date   310 non-null    datetime64[ns]
#  10  Product         310 non-null    object
#  11  Category        310 non-null    object
#  12  Quantity        310 non-null    int64
#  13  Price           310 non-null    int64
#  14  Discount        310 non-null    float64
#  15  Revenue         310 non-null    float64
#  16  Payment_Method  310 non-null    object
# ...

# %% [markdown]
# # Fix Customer Name

# %%
df["Customer_Name"] = (
    df["Customer_Name"]
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
    .str.title()
)

# %% [markdown]
# # Fix Age

# %%
df['Age'].value_counts()
# Out:
# Age
#  27.0     16
#  30.0     15
#  22.0     15
#  38.0     15
#  39.0     14
#  29.0     14
#  24.0     13
#  33.0     13
#  20.0     12
#  25.0     11
#  40.0     11
#  43.0     11
#  28.0      9
#  34.0      9
#  45.0      9
#  23.0      8
#  41.0      8
#  42.0      8
#  36.0      8
#  21.0      8
#  50.0      7
#  46.0      7
#  35.0      7
#  49.0      6
#  999.0     6
#  37.0      6
#  150.0     6
#  32.0      6
#  47.0      6
#  0.0       5
#  44.0      5
#  48.0      5
#  31.0      3
#  26.0      3
# -5.0       1
# Name: count, dtype: int64

# %%
import numpy as np

# %%
df['Age'] = np.where( (df['Age'] <18) |
                     ( df['Age'] >80),
                      np.nan,
                      df['Age'] )

# %%
df['Age'] = df['Age'].fillna((df['Age'].mean()))
df['Age']= df['Age'].astype(int)

# %%
df['Age'].value_counts()
# Out:
# Age
# 33    35
# 27    16
# 38    15
# 30    15
# 22    15
# 29    14
# 39    14
# 24    13
# 20    12
# 40    11
# 43    11
# 25    11
# 34     9
# 28     9
# 45     9
# 36     8
# 21     8
# 23     8
# 41     8
# 42     8
# 46     7
# 50     7
# 35     7
# 49     6
# 32     6
# 47     6
# 37     6
# 44     5
# 48     5
# 31     3
# 26     3
# Name: count, dtype: int64

# %% [markdown]
# # Fix Gender

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# # Fix City

# %%
df['City'].unique()
# Out:
# array(['Delhi', 'Surat', 'Pune', 'Jaipur', 'Ahmedabad', 'Indore',
#        'Lucknow', 'Mumbai', ' Jaipur ', ' Mumb@i ', 'Delh!i'],
#       dtype=object)

# %%
df['City']=df['City'].replace({' Mumb@i ':'Mumbai','Delh!i':'Delhi'})

# %%
df['City'] =df['City'].str.strip()
df['City'].unique()
# Out:
# array(['Delhi', 'Surat', 'Pune', 'Jaipur', 'Ahmedabad', 'Indore',
#        'Lucknow', 'Mumbai'], dtype=object)

# %% [markdown]
# # Fix State

# %%
df['State'] =df['State'].str.strip()
df['State'].unique()
# Out:
# array(['Uttar Pradesh', 'Gujarat', 'Maharashtra', 'Delhi', 'Rajasthan',
#        'Madhya Pradesh', 'GJ', 'gujrat', 'GUJRAT'], dtype=object)

# %%
df['State'] = df['State'].replace({'GJ':'Gujarat','gujrat':'Gujarat','GUJRAT':'Gujarat'})
df['State'].unique()
# Out:
# array(['Uttar Pradesh', 'Gujarat', 'Maharashtra', 'Delhi', 'Rajasthan',
#        'Madhya Pradesh'], dtype=object)

# %% [markdown]
# # Fix Email

# %%
df['Email'] = df['Email'].str.strip()
df['Email'] = df['Email'].str.lower()
df['Email'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Fix Product

# %%
df['Product']=df['Product'].str.strip()
df['Product'].unique()
# Out:
# array(['Mobile', 'Chair', 'Tablet', 'Keyboard', 'Monitor', 'Printer',
#        'Mouse', 'Desk', 'Headphones', 'Laptop'], dtype=object)

# %% [markdown]
# # Fix Category

# %%
df['Category'] =df['Category'].str.strip()
df['Category'].unique()
# Out:
# array(['Accessories', 'Electronic', 'Furniture', 'Electronics',
#        'electronics', 'accessories', 'ELECTRONICS'], dtype=object)

# %%
df[	'Category'] = df[	'Category'].replace({'accessories':'Accessories','electronics':'Electronics','ELECTRONICS':'Electronics','Electronic':'Electronics',})
df['Category'].unique()
# Out:
# array(['Accessories', 'Electronics', 'Furniture'], dtype=object)

# %% [markdown]
# # Fix Quantity

# %%
df['Quantity'].unique()
# Out:
# array([ 1,  5,  0,  2, -2,  3,  4])

# %%
df['Quantity'].value_counts().sort_index()
# Out:
# Quantity
# -2    12
#  0     5
#  1    68
#  2    54
#  3    66
#  4    48
#  5    57
# Name: count, dtype: int64

# %%
 df = df[df['Quantity'] >=1]

# %%
df['Quantity'].unique()
# Out:
# array([1, 5, 2, 3, 4])

# %% [markdown]
# # Fix Phone

# %%
df['Phone'] = df['Phone'].str.strip()
df['Phone'] = df['Phone'].astype(str)

# %%
df1 = df[df['Quantity'] >= 1].copy()

# %%
df['Phone'] = df['Phone'].str.strip()
df['Phone'] = df['Phone'].astype(str)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13088\3827756019.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone'] = df['Phone'].str.strip()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13088\3827756019.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone'] = df['Phone'].astype(str)

# %%
df = df[df['Quantity'] >= 1].copy()

# %%
df['Phone'] = df['Phone'].str.strip()
df['Phone'] = df['Phone'].astype(str)

# %%
df['Phone_Valid'] =( (df['Phone'].str.len() ==10)& (df['Phone'].str.isnumeric()))

# %%
df= df[df['Phone_Valid'] == True]
df
# Out:
#     Order_ID Customer_Name  Age  Gender       City          State  \
# 0       1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1       1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2       1003   Rahul Singh   42  Female       Pune        Gujarat
# 3       1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4       1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..       ...           ...  ...     ...        ...            ...
# 303     1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 304     1005   Pooja Verma   38    Male      Delhi    Maharashtra
# 306     1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307     1008    Amit Kumar   27    Male       Pune      Rajasthan
# 309     1010   Arjun Mehta   33  Female       Pune          Delhi
#
#                Email       Phone Order_Date Delivery_Date  Product  \
# 0    user0@gmail.com  9883197857 2025-01-10    2025-01-15   Mobile
# ...

# %% [markdown]
# # Fix Revenue

# %%
df['Reveune_Valid']= ( df['Revenue'] == ((df['Quantity']*df['Price'])*(1-df['Discount'])))

# %%
df['Reveune_Valid'].value_counts()
# Out:
# Reveune_Valid
# True    279
# Name: count, dtype: int64

# %% [markdown]
# # Fix Date

# %%
df["Order_Date"].dtype
df['Delivery_Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
(df["Delivery_Date"] > df["Order_Date"]).sum()
# Out:
# np.int64(270)

# %%
df
# Out:
#     Order_ID Customer_Name  Age  Gender       City          State  \
# 0       1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1       1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2       1003   Rahul Singh   42  Female       Pune        Gujarat
# 3       1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4       1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..       ...           ...  ...     ...        ...            ...
# 303     1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 304     1005   Pooja Verma   38    Male      Delhi    Maharashtra
# 306     1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307     1008    Amit Kumar   27    Male       Pune      Rajasthan
# 309     1010   Arjun Mehta   33  Female       Pune          Delhi
#
#                Email       Phone Order_Date Delivery_Date  Product  \
# 0    user0@gmail.com  9883197857 2025-01-10    2025-01-15   Mobile
# ...

# %% [markdown]
# # NumPy Feature Engineering.

# %% [markdown]
# # Group by Age

# %%
df['Age_Group'] = np.where(df['Age']<30,'Young',np.where(df['Age']<50,'Adult','Senior'))

# %%
df['Age_Group'].value_counts().sort_values()
# Out:
# Age_Group
# Senior      7
# Young     100
# Adult     172
# Name: count, dtype: int64

# %% [markdown]
# # VIP Customer

# %%
df['VIP_Customer'] = np.where(df['Revenue'] >30000 ,'Yes','No')

# %%
df['VIP_Customer'].value_counts().sort_values()
# Out:
# VIP_Customer
# Yes     82
# No     197
# Name: count, dtype: int64

# %% [markdown]
# # High Rating

# %%
df['High_Rating'] = np.where(df['Rating'] >4 ,'Yes','No')

# %%
df['High_Rating'].value_counts().sort_values()
# Out:
# High_Rating
# Yes     58
# No     221
# Name: count, dtype: int64

# %%
df.to_csv("customer_orders_cleaned.csv", index=False)

# %%
df.to_excel("customer_orders_cleaned.xlsx", index=False)
