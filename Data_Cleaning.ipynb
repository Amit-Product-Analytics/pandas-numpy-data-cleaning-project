# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\customer_orders_raw_messy.csv")
df
# Out:
#      Order_ID Customer_Name    Age  Gender       City          State  \
# 0        1001    Neha Patel   27.0    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36.0    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42.0  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47.0  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38.0    Male      Delhi    Maharashtra
# ..        ...           ...    ...     ...        ...            ...
# 305      1006   Arjun Mehta  150.0  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43.0    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27.0    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48.0  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta  999.0  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# ...

# %%
df.head(20)
# Out:
#     Order_ID Customer_Name    Age  Gender       City           State  \
# 0       1001    Neha Patel   27.0    Male      Delhi   Uttar Pradesh
# 1       1002    Neha Patel   36.0    Male      Surat   Uttar Pradesh
# 2       1003   Rahul Singh   42.0  Female       Pune         Gujarat
# 3       1004   Pooja Verma   47.0  Female     Jaipur     Maharashtra
# 4       1005   Pooja Verma   38.0    Male      Delhi     Maharashtra
# 5       1006   Arjun Mehta  150.0  Female       Pune           Delhi
# 6       1007   Rohit Gupta   43.0    Male  Ahmedabad       Rajasthan
# 7       1008    Amit Kumar   27.0    Male       Pune       Rajasthan
# 8       1009   Arjun Mehta   48.0  Female  Ahmedabad         Gujarat
# 9       1010   Arjun Mehta  999.0  Female       Pune           Delhi
# 10      1011   Arjun Mehta   39.0    Male     Indore       Rajasthan
# 11      1012   Rohit Gupta   44.0  Female       Pune     Maharashtra
# 12      1013   Rohit Gupta   49.0    Male     Jaipur   Uttar Pradesh
# ...

# %%
df.shape
# Out:
# (310, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        310 non-null    int64
#  1   Customer_Name   310 non-null    object
#  2   Age             306 non-null    float64
#  3   Gender          310 non-null    object
#  4   City            310 non-null    object
#  5   State           310 non-null    object
#  6   Email           310 non-null    object
#  7   Phone           310 non-null    object
#  8   Order_Date      310 non-null    object
#  9   Delivery_Date   310 non-null    object
#  10  Product         310 non-null    object
#  11  Category        310 non-null    object
#  12  Quantity        310 non-null    int64
#  13  Price           310 non-null    int64
#  14  Discount        310 non-null    float64
#  15  Revenue         310 non-null    float64
#  16  Payment_Method  310 non-null    object
# ...

# %%
df.describe()
# Out:
#           Order_ID         Age    Quantity         Price    Discount  \
# count   310.000000  306.000000  310.000000    310.000000  310.000000
# mean   1145.822581   54.238562    2.667742  12311.290323    0.103871
# std      89.107862  135.157875    1.718712  15500.726623    0.069798
# min    1001.000000   -5.000000   -2.000000    500.000000    0.000000
# 25%    1068.250000   27.000000    1.000000   1000.000000    0.050000
# 50%    1145.500000   34.000000    3.000000   5000.000000    0.100000
# 75%    1222.750000   41.000000    4.000000  20000.000000    0.150000
# max    1300.000000  999.000000    5.000000  50000.000000    0.200000
#
#              Revenue      Rating
# count     310.000000  310.000000
# mean    30323.870968    3.041935
# std     42893.645270    1.605467
# min       425.000000    0.000000
# 25%      3800.000000    2.000000
# 50%     13500.000000    3.000000
# 75%     37500.000000    4.000000
# max    200000.000000   10.000000

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Customer_Name     0
# Age               4
# Gender            0
# City              0
# State             0
# Email             0
# Phone             0
# Order_Date        0
# Delivery_Date     0
# Product           0
# Category          0
# Quantity          0
# Price             0
# Discount          0
# Revenue           0
# Payment_Method    0
# Rating            0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 305     True
# 306     True
# 307     True
# 308     True
# 309     True
# Length: 310, dtype: bool

# %%
df['Gender'].unique
# Out:
# <bound method Series.unique of 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 305    Female
# 306      Male
# 307      Male
# 308    Female
# 309    Female
# Name: Gender, Length: 310, dtype: object>

# %%
df['Category'].unique
# Out:
# <bound method Series.unique of 0      Accessories
# 1       Electronic
# 2        Furniture
# 3      Electronics
# 4        Furniture
#           ...
# 305    electronics
# 306    accessories
# 307    electronics
# 308    accessories
# 309     Electronic
# Name: Category, Length: 310, dtype: object>

# %%
df['Payment_Method'].unique
# Out:
# <bound method Series.unique of 0             Cash
# 1              UPI
# 2             Cash
# 3             Cash
# 4             Cash
#           ...
# 305    Credit Card
# 306    Credit Card
# 307    Credit Card
# 308    Credit Card
# 309            UPI
# Name: Payment_Method, Length: 310, dtype: object>

# %%
df.head()
# Out:
#    Order_ID Customer_Name   Age  Gender    City          State  \
# 0      1001    Neha Patel  27.0    Male   Delhi  Uttar Pradesh
# 1      1002    Neha Patel  36.0    Male   Surat  Uttar Pradesh
# 2      1003   Rahul Singh  42.0  Female    Pune        Gujarat
# 3      1004   Pooja Verma  47.0  Female  Jaipur    Maharashtra
# 4      1005   Pooja Verma  38.0    Male   Delhi    Maharashtra
#
#              Email       Phone  Order_Date Delivery_Date Product     Category  \
# 0  user0@gmail.com  9883197857  2025-01-10    2025-01-15  Mobile  Accessories
# 1  user1@gmail.com  9897226012  2025-01-10    2025-01-15   Chair   Electronic
# 2  user2@gmail.com  9830868105  2025-01-10    2025-01-15  Tablet    Furniture
# 3  user3@gmail.com  9871662963  2025-01-10    2025-01-15   Chair  Electronics
# 4  user4@gmail.com  9898753260  2025-01-10    2025-01-15  Tablet    Furniture
#
#    Quantity  Price  Discount  Revenue Payment_Method  Rating
# ...

# %% [markdown]
# # Fix Customer_name

# %%
df['Customer_Name'] = df['Customer_Name'].str.strip()
df
# Out:
#      Order_ID Customer_Name    Age  Gender       City          State  \
# 0        1001    Neha Patel   27.0    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36.0    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42.0  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47.0  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38.0    Male      Delhi    Maharashtra
# ..        ...           ...    ...     ...        ...            ...
# 305      1006   Arjun Mehta  150.0  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43.0    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27.0    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48.0  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta  999.0  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# ...

# %% [markdown]
# # Fix Age

# %%
df['Age'].describe()
# Out:
# count    306.000000
# mean      54.238562
# std      135.157875
# min       -5.000000
# 25%       27.000000
# 50%       34.000000
# 75%       41.000000
# max      999.000000
# Name: Age, dtype: float64

# %%
import numpy as np

# %%
import numpy as np

df["Age"] = np.where(
    (df["Age"] < 18) |
    (df["Age"] > 80),
    np.nan,
    df["Age"]
)
df
# Out:
#      Order_ID Customer_Name   Age  Gender       City          State  \
# 0        1001    Neha Patel  27.0    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel  36.0    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh  42.0  Female       Pune        Gujarat
# 3        1004   Pooja Verma  47.0  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma  38.0    Male      Delhi    Maharashtra
# ..        ...           ...   ...     ...        ...            ...
# 305      1006   Arjun Mehta   NaN  Female       Pune          Delhi
# 306      1007   Rohit Gupta  43.0    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar  27.0    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta  48.0  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta   NaN  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# 0    user0@gmail.com  9883197857  2025-01-10    2025-01-15    Mobile
# ...

# %%
df["Age"] = df["Age"].fillna(df["Age"].median()).astype(int)
df
# Out:
#      Order_ID Customer_Name  Age  Gender       City          State  \
# 0        1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..        ...           ...  ...     ...        ...            ...
# 305      1006   Arjun Mehta   34  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta   34  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# 0    user0@gmail.com  9883197857  2025-01-10    2025-01-15    Mobile
# ...

# %% [markdown]
# # Fix Gender

# %%
df['Gender'].value_counts(dropna = False)
# Out:
# Gender
# Male      162
# Female    148
# Name: count, dtype: int64

# %% [markdown]
# # Fix City

# %%
df['City'].value_counts(dropna = False)
# Out:
# City
# Delhi        51
# Indore       49
# Ahmedabad    37
# Jaipur       35
# Pune         34
# Surat        32
# Lucknow      29
# Mumbai       28
#  Jaipur       7
#  Mumb@i       4
# Delh!i        4
# Name: count, dtype: int64

# %%
df['City'] =df['City'].str.strip()
df
# Out:
#      Order_ID Customer_Name  Age  Gender       City          State  \
# 0        1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..        ...           ...  ...     ...        ...            ...
# 305      1006   Arjun Mehta   34  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta   34  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# 0    user0@gmail.com  9883197857  2025-01-10    2025-01-15    Mobile
# ...

# %%
df['City'] =df['City'].replace({'Mumb@i':'Mumbai'}).astype('string')
df['City'].value_counts(dropna = False)
# Out:
# City
# Delhi        55
# Indore       49
# Jaipur       42
# Ahmedabad    37
# Pune         34
# Surat        32
# Mumbai       32
# Lucknow      29
# Name: count, dtype: Int64

# %% [markdown]
# # Fix Gender

# %%
df['City'] = df['City'].str.strip()
df['Gender'].value_counts(dropna = False)
# Out:
# Gender
# Male      162
# Female    148
# Name: count, dtype: int64

# %% [markdown]
#  # Fix State

# %%
df['State'] = df['State'].str.strip()
df['State'].value_counts(dropna = False)
# Out:
# State
# Maharashtra       59
# Gujarat           55
# Rajasthan         49
# Uttar Pradesh     47
# Delhi             47
# Madhya Pradesh    38
# GJ                 7
# gujrat             5
# GUJRAT             3
# Name: count, dtype: int64

# %%
df['State'] = df['State'].replace({'GJ':'Gujarat','gujrat':'Gujarat','GUJRAT':'Gujarat'})
df['State'].value_counts(dropna = False)
df

# %% [markdown]
# # Fix Email

# %%
df['Email'] = df['Email'].str.strip()
df['Email'] = df['Email'].str.lower()
df
# Out:
#      Order_ID Customer_Name  Age  Gender       City          State  \
# 0        1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..        ...           ...  ...     ...        ...            ...
# 305      1006   Arjun Mehta   34  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta   34  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# 0    user0@gmail.com  9883197857  2025-01-10    2025-01-15    Mobile
# ...

# %% [markdown]
# # Fix Phone no

# %% [markdown]
# df["Phone"] = df["Phone"].astype(str)
# df["Phone"].str.len()
# df[df["Phone"].str.len() != 10]
# df[df["Phone"].str.isnumeric() == False]
# df["Phone_Valid"] = (
#     (df["Phone"].str.len() == 10)
#     &
#     (df["Phone"].str.isnumeric())
# )
# df[["Phone","Phone_Valid"]]
# import numpy as np
#
# df.loc[
#     df["Phone_Valid"] == False,
#     "Phone"
# ] = np.nan
#
# df["Phone"].isnull().sum()
# df

# %%
df["Phone"].isnull().sum()
# Out:
# np.int64(15)

# %% [markdown]
# # Fix Product

# %%
df['Product'] = df['Product'].str.strip()
df
df['Product'].value_counts(dropna = False )
# Out:
# Product
# Chair         36
# Keyboard      36
# Tablet        35
# Mobile        31
# Monitor       31
# Mouse         30
# Printer       29
# Headphones    29
# Desk          27
# Laptop        26
# Name: count, dtype: int64

# %% [markdown]
# # Fix Category

# %%
df['Category'] = df['Category'].str.strip()
df[	'Category'].value_counts(dropna =False)
# Out:
# Category
# Furniture      53
# Accessories    51
# accessories    47
# electronics    43
# ELECTRONICS    42
# Electronic     41
# Electronics    33
# Name: count, dtype: int64

# %%
df[	'Category'] = df[	'Category'].replace({'accessories':'Accessories','electronics':'Electronics','ELECTRONICS':'Electronics','Electronic':'Electronics',})
df[	'Category'].value_counts(dropna =False)
df
# Out:
#      Order_ID Customer_Name  Age  Gender       City          State  \
# 0        1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..        ...           ...  ...     ...        ...            ...
# 305      1006   Arjun Mehta   34  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta   34  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# 0    user0@gmail.com  9883197857  2025-01-10    2025-01-15    Mobile
# ...

# %% [markdown]
# # FIX  Revenue

# %%
df[	'Revenue'].value_counts(dropna =False)
df.sort_values('Revenue')
df["Revenue_Valid"] = (
    df["Revenue"] ==
    (df["Quantity"] * df["Price"] * (1 - df["Discount"]))
)
df["Revenue_Valid"].value_counts()
df["Revenue"] = (
    df["Quantity"] *
    df["Price"] *
    (1 - df["Discount"])
).round(2)

df["Revenue_Valid"].value_counts()
df
# Out:
#      Order_ID Customer_Name  Age  Gender       City          State  \
# 0        1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..        ...           ...  ...     ...        ...            ...
# 305      1006   Arjun Mehta   34  Female       Pune          Delhi
# 306      1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27    Male       Pune      Rajasthan
# 308      1009   Arjun Mehta   48  Female  Ahmedabad        Gujarat
# 309      1010   Arjun Mehta   34  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date   Product  \
# 0    user0@gmail.com  9883197857  2025-01-10    2025-01-15    Mobile
# ...

# %% [markdown]
# # Fix Quantity

# %%
df['Quantity'].value_counts( dropna = False)
# Out:
# Quantity
#  1    68
#  3    66
#  5    57
#  2    54
#  4    48
# -2    12
#  0     5
# Name: count, dtype: int64

# %%
df[df["Quantity"] <= 0]
# Out:
#      Order_ID Customer_Name  Age  Gender       City           State  \
# 5        1006   Arjun Mehta   34  Female       Pune           Delhi
# 8        1009   Arjun Mehta   48  Female  Ahmedabad         Gujarat
# 11       1012   Rohit Gupta   44  Female       Pune     Maharashtra
# 43       1044    Neha Patel   42  Female    Lucknow       Rajasthan
# 81       1082   Rohit Gupta   42  Female     Indore       Rajasthan
# 92       1093    Neha Patel   32  Female      Delhi           Delhi
# 127      1128  Vikram Joshi   38    Male       Pune  Madhya Pradesh
# 151      1152  Vikram Joshi   45    Male     Indore     Maharashtra
# 186      1187    Sneha Jain   35    Male     Jaipur         Gujarat
# 203      1204    Neha Patel   34    Male     Indore       Rajasthan
# 208      1209    Sneha Jain   47  Female      Delhi         Gujarat
# 243      1244    Neha Patel   34  Female     Indore     Maharashtra
# 254      1255   Rohit Gupta   28    Male       Pune   Uttar Pradesh
# ...

# %%
(df["Quantity"] <= 0).sum()
# Out:
# np.int64(17)

# %%
df = df[df["Quantity"] > 0]

# %%
df["Quantity"].value_counts(dropna=False)
# Out:
# Quantity
# 1    68
# 3    66
# 5    57
# 2    54
# 4    48
# Name: count, dtype: int64

# %%
df
# Out:
#      Order_ID Customer_Name  Age  Gender       City          State  \
# 0        1001    Neha Patel   27    Male      Delhi  Uttar Pradesh
# 1        1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38    Male      Delhi    Maharashtra
# ..        ...           ...  ...     ...        ...            ...
# 303      1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 304      1005   Pooja Verma   38    Male      Delhi    Maharashtra
# 306      1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27    Male       Pune      Rajasthan
# 309      1010   Arjun Mehta   34  Female       Pune          Delhi
#
#                Email       Phone  Order_Date Delivery_Date  Product  \
# 0    user0@gmail.com  9883197857  2025-01-10    2025-01-15   Mobile
# ...

# %% [markdown]
#  # Fix Rating

# %%
df["Rating"].value_counts(dropna=False)
# Out:
# Rating
# 4     65
# 1     62
# 3     59
# 5     54
# 2     42
# 0      6
# 6      3
# 10     2
# Name: count, dtype: int64

# %%
df = df[df["Rating"] <= 5]

# %%
df["Rating"].value_counts(dropna=False)
# Out:
# Rating
# 4    65
# 1    62
# 3    59
# 5    54
# 2    42
# 0     6
# Name: count, dtype: int64

# %%
df = df[df["Rating"] != 0]
df["Rating"].value_counts(dropna=False)
# Out:
# Rating
# 4    65
# 1    62
# 3    59
# 5    54
# 2    42
# Name: count, dtype: int64

# %%
df = df[(df["Rating"] >= 1) & (df["Rating"] <= 5)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 282 entries, 1 to 309
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        282 non-null    int64
#  1   Customer_Name   282 non-null    object
#  2   Age             282 non-null    int64
#  3   Gender          282 non-null    object
#  4   City            282 non-null    string
#  5   State           282 non-null    object
#  6   Email           282 non-null    object
#  7   Phone           268 non-null    object
#  8   Order_Date      282 non-null    object
#  9   Delivery_Date   282 non-null    object
#  10  Product         282 non-null    object
#  11  Category        282 non-null    object
#  12  Quantity        282 non-null    int64
#  13  Price           282 non-null    int64
#  14  Discount        282 non-null    float64
#  15  Revenue         282 non-null    float64
#  16  Payment_Method  282 non-null    object
# ...

# %% [markdown]
# # Inspect Date Columns

# %%
df[["Order_Date", "Delivery_Date"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 282 entries, 1 to 309
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_Date     282 non-null    object
#  1   Delivery_Date  282 non-null    object
# dtypes: object(2)
# memory usage: 6.6+ KB

# %%
df["Order_Date"].dtype
df["Delivery_Date"].dtype
# Out:
# dtype('O')

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"], errors="coerce")
df["Order_Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
(df["Delivery_Date"] < df["Order_Date"]).sum()
# Out:
# np.int64(0)

# %%
df.to_csv("customer_orders_cleaned.csv", index=False)

# %%
df
# Out:
#      Order_ID Customer_Name  Age  Gender       City          State  \
# 1        1002    Neha Patel   36    Male      Surat  Uttar Pradesh
# 2        1003   Rahul Singh   42  Female       Pune        Gujarat
# 3        1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 4        1005   Pooja Verma   38    Male      Delhi    Maharashtra
# 6        1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# ..        ...           ...  ...     ...        ...            ...
# 303      1004   Pooja Verma   47  Female     Jaipur    Maharashtra
# 304      1005   Pooja Verma   38    Male      Delhi    Maharashtra
# 306      1007   Rohit Gupta   43    Male  Ahmedabad      Rajasthan
# 307      1008    Amit Kumar   27    Male       Pune      Rajasthan
# 309      1010   Arjun Mehta   34  Female       Pune          Delhi
#
#                Email       Phone Order_Date Delivery_Date  Product  \
# 1    user1@gmail.com  9897226012 2025-01-10    2025-01-15    Chair
# ...

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\ASUS'
